# %%
# %load_ext autoreload
# %autoreload 2

import argparse
import os
import sys
import pathlib
from typing import Type, Callable

import gymnasium as gym

sys.modules["gym"] = gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.utils import safe_mean
from stable_baselines3.common.logger import Image
import numpy as np
import matplotlib.pyplot as plt


from swarm.bas import Agent, BASEnv, Blueprint, RenderWrapper, Swarm, wrappers
from swarm.analysis import policy,trajectories, reward
from swarm.training.train import create_parallel_env, SuccessRateCallback, DrawTrajectoriesCallback, RewardHeatmapCallback

# %%
class RelativeGoalInsideGridEnv(gym.Wrapper):
    def __init__(
        self,
        collision_termination: bool = False,
        collision_reward: int = 0,
        distance_reward_transform: Callable[[float], float] = lambda d: -d, 
        target_radius: float = 3,
        window_scale: float | None = 5,
    ):
        blueprint = Blueprint(
            world_size=np.array([200, 200]),
        )
        agent = Agent(
            radius=1,
            max_velocity=1,
            max_acceleration=0.2,
        )
        # Static grid.
        swarm = Swarm(
            num_boids=100,
            radius=2,
            max_velocity=None,
            reset_positions=np.stack(
                np.meshgrid(np.linspace(55, 145, 10), np.linspace(55, 145, 10)), -1
            ).reshape(-1, 2),
            max_acceleration=1,
            separation_range=1,
            cohesion_range=1,
            alignment_range=1,
            steering_weights=(1, 1, 1),
            obstacle_margin=1,
        )
        env = BASEnv(blueprint, agent, swarm)

        target = np.array([100, 100])
        env = wrappers.TargetDirectionAndSectionObservationWrapper(
            env, num_sections=8, max_range=20, position=target, subtract_radius=True
        )
        env = wrappers.TargetRewardWrapper(
            env,
            position=target,
            target_radius=target_radius,
            target_reward=100,
            distance_reward_transform=lambda d: -d
        )
        env = wrappers.BoidCollisionWrapper(
            env,
            collision_termination=collision_termination,
            collision_reward=collision_reward,
            add_reward=True,
        )

        if window_scale is not None:
            env = RenderWrapper(env, window_scale=window_scale)

        env = wrappers.RelativeRotationWrapper(env)
        env = wrappers.FlattenObservationWrapper(env)

        env = gym.wrappers.TimeLimit(env, 500)

        env = wrappers.TrajectoryWrapper(env)

        super().__init__(env)

# %%
train_steps = [
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=False,
            collision_reward=0,
            distance_reward_transform=lambda d: -d,
            target_radius=3,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=40,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=40,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=30,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=20,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=10,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d/500,
            target_radius=3,
            window_scale=window_scale
        ),
    ),
]

# %%
runs_directory = pathlib.Path("runs")
tensorboard_directory = runs_directory / "tensorboard"

experiment_name = "relative_goal_inside_grid/fifth_try"
experiment_path = runs_directory / experiment_name

num_processes = 12


model = None
for i, (num_steps, create_env) in enumerate(train_steps):

    env = create_parallel_env(
        create_env,
        num_processes,
        ["is_success", "agent_trajectory"],
    )

    if model is None:
        model = PPO(
            "MlpPolicy",
            env,
            verbose=1,
            tensorboard_log=tensorboard_directory / experiment_name,
        )
    else:
        model.set_env(env)

    model.learn(
        total_timesteps=num_steps,
        # progress_bar=True,
        callback=[SuccessRateCallback(), DrawTrajectoriesCallback(create_env(5)), RewardHeatmapCallback(create_env())],
        reset_num_timesteps=False,
    )

    model.save(experiment_path)
# Out:
# Using cpu device
# Logging to runs/tensorboard/relative_goal_inside_grid/fifth_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -133     |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 1451     |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 24576    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -128         |
# |    success_rate         | 0.0309       |
# | time/                   |              |
# |    fps                  | 1670         |
# |    iterations           | 2            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0040256013 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.753        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0014      |
# |    std                  | 0.993        |
# |    value_loss           | 2.66         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | -119         |
# |    success_rate         | 0.06         |
# | time/                   |              |
# |    fps                  | 1730         |
# |    iterations           | 3            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0038101918 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.695        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0022      |
# |    std                  | 0.978        |
# |    value_loss           | 12.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 489          |
# |    ep_rew_mean          | -116         |
# |    success_rate         | 0.05         |
# | time/                   |              |
# |    fps                  | 1768         |
# |    iterations           | 4            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0037913248 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.65         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00215     |
# |    std                  | 0.966        |
# |    value_loss           | 12.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 478         |
# |    ep_rew_mean          | -100        |
# |    success_rate         | 0.1         |
# | time/                   |             |
# |    fps                  | 1786        |
# |    iterations           | 5           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004225848 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.738       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.497       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00304    |
# |    std                  | 0.963       |
# |    value_loss           | 8.87        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 449        |
# |    ep_rew_mean          | -55.8      |
# |    success_rate         | 0.33       |
# | time/                   |            |
# |    fps                  | 1802       |
# |    iterations           | 6          |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 147456     |
# | train/                  |            |
# |    approx_kl            | 0.00606216 |
# |    clip_fraction        | 0.0646     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.559      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.64       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00367   |
# |    std                  | 0.954      |
# |    value_loss           | 32.4       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 352         |
# |    ep_rew_mean          | 19.2        |
# |    success_rate         | 0.78        |
# | time/                   |             |
# |    fps                  | 1820        |
# |    iterations           | 7           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.005848024 |
# |    clip_fraction        | 0.067       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.377       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00333    |
# |    std                  | 0.948       |
# |    value_loss           | 104         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 242          |
# |    ep_rew_mean          | 59.2         |
# |    success_rate         | 0.97         |
# | time/                   |              |
# |    fps                  | 1829         |
# |    iterations           | 8            |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0073320996 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.7         |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00463     |
# |    std                  | 0.928        |
# |    value_loss           | 210          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | 59.1         |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 1837         |
# |    iterations           | 9            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0064941547 |
# |    clip_fraction        | 0.0741       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.41         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 152          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00405     |
# |    std                  | 0.914        |
# |    value_loss           | 266          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | 66.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1843         |
# |    iterations           | 10           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0060817786 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.569        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 107          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00353     |
# |    std                  | 0.901        |
# |    value_loss           | 230          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 166         |
# |    ep_rew_mean          | 72.4        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1838        |
# |    iterations           | 11          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.006201479 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 0.885       |
# |    value_loss           | 221         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 74.3         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1834         |
# |    iterations           | 12           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0067423224 |
# |    clip_fraction        | 0.0786       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.57        |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.7         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00416     |
# |    std                  | 0.872        |
# |    value_loss           | 198          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | 80.2        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1839        |
# |    iterations           | 13          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 319488      |
# | train/                  |             |
# |    approx_kl            | 0.005787334 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.783       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00309    |
# |    std                  | 0.863       |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 115         |
# |    ep_rew_mean          | 81          |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1846        |
# |    iterations           | 14          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.005367748 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.852       |
# |    value_loss           | 152         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 109          |
# |    ep_rew_mean          | 82.3         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1846         |
# |    iterations           | 15           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0052908375 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.49        |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87.4         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00228     |
# |    std                  | 0.839        |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | 82.2         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1850         |
# |    iterations           | 16           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0049032588 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.46        |
# |    explained_variance   | 0.84         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50           |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00187     |
# |    std                  | 0.83         |
# |    value_loss           | 112          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | 82.2        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1852        |
# |    iterations           | 17          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.005452536 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00227    |
# |    std                  | 0.82        |
# |    value_loss           | 93.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 105          |
# |    ep_rew_mean          | 82.2         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1855         |
# |    iterations           | 18           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0058647133 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.4         |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00286     |
# |    std                  | 0.802        |
# |    value_loss           | 83.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 83.4        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1857        |
# |    iterations           | 19          |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 466944      |
# | train/                  |             |
# |    approx_kl            | 0.005292173 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.37       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00231    |
# |    std                  | 0.787       |
# |    value_loss           | 79.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 82.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1857         |
# |    iterations           | 20           |
# |    time_elapsed         | 264          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0045681563 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.9         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.778        |
# |    value_loss           | 74.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 95.7         |
# |    ep_rew_mean          | 84.2         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1860         |
# |    iterations           | 21           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 516096       |
# | train/                  |              |
# |    approx_kl            | 0.0051251403 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.9         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00143     |
# |    std                  | 0.761        |
# |    value_loss           | 68.5         |
# ------------------------------------------
# Logging to runs/tensorboard/relative_goal_inside_grid/fifth_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34.3     |
# |    ep_rew_mean     | 20.3     |
# |    success_rate    | 0.3      |
# | time/              |          |
# |    fps             | 1472     |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 540672   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.3        |
# |    ep_rew_mean          | 20.7        |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1648        |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 565248      |
# | train/                  |             |
# |    approx_kl            | 0.003439327 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.26       |
# |    explained_variance   | 0.0679      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 164         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.752       |
# |    value_loss           | 236         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.7         |
# |    ep_rew_mean          | 15.2         |
# |    success_rate         | 0.27         |
# | time/                   |              |
# |    fps                  | 1726         |
# |    iterations           | 3            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0044569694 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.333        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 96.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.738        |
# |    value_loss           | 253          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.2         |
# |    ep_rew_mean          | 19           |
# |    success_rate         | 0.3          |
# | time/                   |              |
# |    fps                  | 1763         |
# |    iterations           | 4            |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0041356157 |
# |    clip_fraction        | 0.0386       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.23        |
# |    explained_variance   | 0.444        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.7         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00106     |
# |    std                  | 0.735        |
# |    value_loss           | 206          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.2        |
# |    ep_rew_mean          | 20.4        |
# |    success_rate         | 0.32        |
# | time/                   |             |
# |    fps                  | 1793        |
# |    iterations           | 5           |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.004070575 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00157    |
# |    std                  | 0.733       |
# |    value_loss           | 211         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40         |
# |    ep_rew_mean          | 23         |
# |    success_rate         | 0.34       |
# | time/                   |            |
# |    fps                  | 1799       |
# |    iterations           | 6          |
# |    time_elapsed         | 81         |
# |    total_timesteps      | 663552     |
# | train/                  |            |
# |    approx_kl            | 0.00556751 |
# |    clip_fraction        | 0.051      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.2       |
# |    explained_variance   | 0.492      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 77         |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00212   |
# |    std                  | 0.723      |
# |    value_loss           | 191        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.6        |
# |    ep_rew_mean          | 19.2        |
# |    success_rate         | 0.3         |
# | time/                   |             |
# |    fps                  | 1811        |
# |    iterations           | 7           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.004406707 |
# |    clip_fraction        | 0.0425      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.1        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00119    |
# |    std                  | 0.726       |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.9        |
# |    ep_rew_mean          | 11.5        |
# |    success_rate         | 0.23        |
# | time/                   |             |
# |    fps                  | 1808        |
# |    iterations           | 8           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 712704      |
# | train/                  |             |
# |    approx_kl            | 0.004888564 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00168    |
# |    std                  | 0.721       |
# |    value_loss           | 210         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.1        |
# |    ep_rew_mean          | 17          |
# |    success_rate         | 0.28        |
# | time/                   |             |
# |    fps                  | 1819        |
# |    iterations           | 9           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.005108405 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00106    |
# |    std                  | 0.71        |
# |    value_loss           | 214         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 38.1     |
# |    ep_rew_mean          | 17.3     |
# |    success_rate         | 0.28     |
# | time/                   |          |
# |    fps                  | 1822     |
# |    iterations           | 10       |
# |    time_elapsed         | 134      |
# |    total_timesteps      | 761856   |
# | train/                  |          |
# |    approx_kl            | 0.004367 |
# |    clip_fraction        | 0.0411   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.14    |
# |    explained_variance   | 0.566    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 125      |
# |    n_updates            | 300      |
# |    policy_gradient_loss | -0.0013  |
# |    std                  | 0.704    |
# |    value_loss           | 204      |
# --------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.7         |
# |    ep_rew_mean          | 19.9         |
# |    success_rate         | 0.31         |
# | time/                   |              |
# |    fps                  | 1820         |
# |    iterations           | 11           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0049436116 |
# |    clip_fraction        | 0.0506       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.572        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94           |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00185     |
# |    std                  | 0.697        |
# |    value_loss           | 186          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.3         |
# |    ep_rew_mean          | 22.9         |
# |    success_rate         | 0.33         |
# | time/                   |              |
# |    fps                  | 1830         |
# |    iterations           | 12           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 811008       |
# | train/                  |              |
# |    approx_kl            | 0.0049674003 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.582        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.687        |
# |    value_loss           | 212          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | 20.8        |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1833        |
# |    iterations           | 13          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.004963648 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00211    |
# |    std                  | 0.678       |
# |    value_loss           | 213         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.1        |
# |    ep_rew_mean          | 20.8        |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1840        |
# |    iterations           | 14          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 860160      |
# | train/                  |             |
# |    approx_kl            | 0.004382416 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 0.67        |
# |    value_loss           | 232         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.4        |
# |    ep_rew_mean          | 21.1        |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 1844        |
# |    iterations           | 15          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.004717732 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.559       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00195    |
# |    std                  | 0.67        |
# |    value_loss           | 215         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | 11.7        |
# |    success_rate         | 0.22        |
# | time/                   |             |
# |    fps                  | 1845        |
# |    iterations           | 16          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 909312      |
# | train/                  |             |
# |    approx_kl            | 0.005912153 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00162    |
# |    std                  | 0.661       |
# |    value_loss           | 194         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.1         |
# |    ep_rew_mean          | 12.2         |
# |    success_rate         | 0.23         |
# | time/                   |              |
# |    fps                  | 1846         |
# |    iterations           | 17           |
# |    time_elapsed         | 226          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0058412286 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.98        |
# |    explained_variance   | 0.597        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00184     |
# |    std                  | 0.648        |
# |    value_loss           | 216          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35.5         |
# |    ep_rew_mean          | 28.3         |
# |    success_rate         | 0.38         |
# | time/                   |              |
# |    fps                  | 1847         |
# |    iterations           | 18           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 958464       |
# | train/                  |              |
# |    approx_kl            | 0.0047131483 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0.613        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 67           |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00109     |
# |    std                  | 0.644        |
# |    value_loss           | 209          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.4        |
# |    ep_rew_mean          | 23.1        |
# |    success_rate         | 0.34        |
# | time/                   |             |
# |    fps                  | 1850        |
# |    iterations           | 19          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.005280211 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 77.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00114    |
# |    std                  | 0.633       |
# |    value_loss           | 235         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.3        |
# |    ep_rew_mean          | 18.2        |
# |    success_rate         | 0.29        |
# | time/                   |             |
# |    fps                  | 1846        |
# |    iterations           | 20          |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.005422257 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 92.6        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00132    |
# |    std                  | 0.628       |
# |    value_loss           | 232         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.9         |
# |    ep_rew_mean          | 19.7         |
# |    success_rate         | 0.31         |
# | time/                   |              |
# |    fps                  | 1848         |
# |    iterations           | 21           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 1032192      |
# | train/                  |              |
# |    approx_kl            | 0.0052823983 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.622        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00186     |
# |    std                  | 0.624        |
# |    value_loss           | 241          |
# ------------------------------------------
# Logging to runs/tensorboard/relative_goal_inside_grid/fifth_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 39.9     |
# |    ep_rew_mean     | 32.4     |
# |    success_rate    | 0.43     |
# | time/              |          |
# |    fps             | 1475     |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1056768  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 37.5         |
# |    ep_rew_mean          | 20.5         |
# |    success_rate         | 0.31         |
# | time/                   |              |
# |    fps                  | 1649         |
# |    iterations           | 2            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 1081344      |
# | train/                  |              |
# |    approx_kl            | 0.0051404596 |
# |    clip_fraction        | 0.0548       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.85        |
# |    explained_variance   | 0.65         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 82.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.611        |
# |    value_loss           | 242          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.4        |
# |    ep_rew_mean          | 27.3        |
# |    success_rate         | 0.37        |
# | time/                   |             |
# |    fps                  | 1712        |
# |    iterations           | 3           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 1105920     |
# | train/                  |             |
# |    approx_kl            | 0.005819544 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 76.7        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000749   |
# |    std                  | 0.606       |
# |    value_loss           | 225         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 40.1        |
# |    ep_rew_mean          | 29          |
# |    success_rate         | 0.4         |
# | time/                   |             |
# |    fps                  | 1748        |
# |    iterations           | 4           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 1130496     |
# | train/                  |             |
# |    approx_kl            | 0.005715648 |
# |    clip_fraction        | 0.0617      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.599       |
# |    value_loss           | 259         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.4         |
# |    ep_rew_mean          | 17.4         |
# |    success_rate         | 0.29         |
# | time/                   |              |
# |    fps                  | 1782         |
# |    iterations           | 5            |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 1155072      |
# | train/                  |              |
# |    approx_kl            | 0.0061848797 |
# |    clip_fraction        | 0.064        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.79        |
# |    explained_variance   | 0.652        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 132          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 0.591        |
# |    value_loss           | 250          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.5        |
# |    ep_rew_mean          | 33.1        |
# |    success_rate         | 0.45        |
# | time/                   |             |
# |    fps                  | 1805        |
# |    iterations           | 6           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.006110584 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 99.4        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00144    |
# |    std                  | 0.584       |
# |    value_loss           | 227         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 41.1         |
# |    ep_rew_mean          | 28.5         |
# |    success_rate         | 0.4          |
# | time/                   |              |
# |    fps                  | 1816         |
# |    iterations           | 7            |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 1204224      |
# | train/                  |              |
# |    approx_kl            | 0.0059185917 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 0.66         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 150          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00209     |
# |    std                  | 0.576        |
# |    value_loss           | 262          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 35           |
# |    ep_rew_mean          | 27.6         |
# |    success_rate         | 0.37         |
# | time/                   |              |
# |    fps                  | 1829         |
# |    iterations           | 8            |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 1228800      |
# | train/                  |              |
# |    approx_kl            | 0.0065515265 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 138          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 0.572        |
# |    value_loss           | 246          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 38.9         |
# |    ep_rew_mean          | 30.5         |
# |    success_rate         | 0.41         |
# | time/                   |              |
# |    fps                  | 1838         |
# |    iterations           | 9            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 1253376      |
# | train/                  |              |
# |    approx_kl            | 0.0065124272 |
# |    clip_fraction        | 0.0693       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 142          |
# |    n_updates            | 500          |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0123577295 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.139       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 80.5         |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | 0.00132      |
# |    std                  | 0.27         |
# |    value_loss           | 186          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.5        |
# |    ep_rew_mean          | 25.3        |
# |    success_rate         | 0.38        |
# | time/                   |             |
# |    fps                  | 1374        |
# |    iterations           | 6           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 3244032     |
# | train/                  |             |
# |    approx_kl            | 0.012728018 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.134      |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.3        |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | 0.00176     |
# |    std                  | 0.269       |
# |    value_loss           | 180         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.8        |
# |    ep_rew_mean          | 29.7        |
# |    success_rate         | 0.44        |
# | time/                   |             |
# |    fps                  | 1397        |
# |    iterations           | 7           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 3268608     |
# | train/                  |             |
# |    approx_kl            | 0.014629938 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.2        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | 0.00195     |
# |    std                  | 0.266       |
# |    value_loss           | 193         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73          |
# |    ep_rew_mean          | 33.8        |
# |    success_rate         | 0.48        |
# | time/                   |             |
# |    fps                  | 1423        |
# |    iterations           | 8           |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 3293184     |
# | train/                  |             |
# |    approx_kl            | 0.013868322 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.101      |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 132         |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | 0.00258     |
# |    std                  | 0.264       |
# |    value_loss           | 181         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.1        |
# |    ep_rew_mean          | 38.4        |
# |    success_rate         | 0.51        |
# | time/                   |             |
# |    fps                  | 1401        |
# |    iterations           | 9           |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 3317760     |
# | train/                  |             |
# |    approx_kl            | 0.014073443 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0656     |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.6        |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | 0.00219     |
# |    std                  | 0.26        |
# |    value_loss           | 177         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.1        |
# |    ep_rew_mean          | 35.8        |
# |    success_rate         | 0.5         |
# | time/                   |             |
# |    fps                  | 1408        |
# |    iterations           | 10          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 3342336     |
# | train/                  |             |
# |    approx_kl            | 0.015031423 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0402     |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | 0.00328     |
# |    std                  | 0.257       |
# |    value_loss           | 170         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.6        |
# |    ep_rew_mean          | 31.1        |
# |    success_rate         | 0.46        |
# | time/                   |             |
# |    fps                  | 1428        |
# |    iterations           | 11          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 3366912     |
# | train/                  |             |
# |    approx_kl            | 0.014538529 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0151     |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.1        |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | 0.00314     |
# |    std                  | 0.255       |
# |    value_loss           | 174         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.6        |
# |    ep_rew_mean          | 32.9        |
# |    success_rate         | 0.47        |
# | time/                   |             |
# |    fps                  | 1456        |
# |    iterations           | 12          |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 3391488     |
# | train/                  |             |
# |    approx_kl            | 0.014177362 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.00065     |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | 0.00233     |
# |    std                  | 0.254       |
# |    value_loss           | 156         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 61.1       |
# |    ep_rew_mean          | 35.8       |
# |    success_rate         | 0.47       |
# | time/                   |            |
# |    fps                  | 1471       |
# |    iterations           | 13         |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 3416064    |
# | train/                  |            |
# |    approx_kl            | 0.01574379 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.00169    |
# |    explained_variance   | 0.78       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 80.4       |
# |    n_updates            | 1380       |
# |    policy_gradient_loss | 0.00323    |
# |    std                  | 0.253      |
# |    value_loss           | 161        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.6        |
# |    ep_rew_mean          | 31.6        |
# |    success_rate         | 0.46        |
# | time/                   |             |
# |    fps                  | 1461        |
# |    iterations           | 14          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 3440640     |
# | train/                  |             |
# |    approx_kl            | 0.015229262 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0196      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61.8        |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | 0.00359     |
# |    std                  | 0.251       |
# |    value_loss           | 150         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.3        |
# |    ep_rew_mean          | 38.1        |
# |    success_rate         | 0.52        |
# | time/                   |             |
# |    fps                  | 1454        |
# |    iterations           | 15          |
# |    time_elapsed         | 253         |
# |    total_timesteps      | 3465216     |
# | train/                  |             |
# |    approx_kl            | 0.015869707 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0408      |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | 0.00308     |
# |    std                  | 0.25        |
# |    value_loss           | 163         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 68.7       |
# |    ep_rew_mean          | 40.4       |
# |    success_rate         | 0.53       |
# | time/                   |            |
# |    fps                  | 1438       |
# |    iterations           | 16         |
# |    time_elapsed         | 273        |
# |    total_timesteps      | 3489792    |
# | train/                  |            |
# |    approx_kl            | 0.01654378 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 0.0531     |
# |    explained_variance   | 0.798      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 88.5       |
# |    n_updates            | 1410       |
# |    policy_gradient_loss | 0.00334    |
# |    std                  | 0.248      |
# |    value_loss           | 153        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.8        |
# |    ep_rew_mean          | 43.7        |
# |    success_rate         | 0.57        |
# | time/                   |             |
# |    fps                  | 1435        |
# |    iterations           | 17          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 3514368     |
# | train/                  |             |
# |    approx_kl            | 0.014472994 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0671      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.1        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | 0.00391     |
# |    std                  | 0.246       |
# |    value_loss           | 151         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75          |
# |    ep_rew_mean          | 42.1        |
# |    success_rate         | 0.56        |
# | time/                   |             |
# |    fps                  | 1439        |
# |    iterations           | 18          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 3538944     |
# | train/                  |             |
# |    approx_kl            | 0.014177006 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.0886      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.5        |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | 0.0036      |
# |    std                  | 0.243       |
# |    value_loss           | 155         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.2        |
# |    ep_rew_mean          | 43          |
# |    success_rate         | 0.57        |
# | time/                   |             |
# |    fps                  | 1438        |
# |    iterations           | 19          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 3563520     |
# | train/                  |             |
# |    approx_kl            | 0.015652567 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.105       |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 85.7        |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.00384     |
# |    std                  | 0.241       |
# |    value_loss           | 141         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.2        |
# |    ep_rew_mean          | 45.1        |
# |    success_rate         | 0.59        |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 20          |
# |    time_elapsed         | 340         |
# |    total_timesteps      | 3588096     |
# | train/                  |             |
# |    approx_kl            | 0.016607093 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.126       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.2        |
# |    n_updates            | 1450        |
# |    policy_gradient_loss | 0.00309     |
# |    std                  | 0.238       |
# |    value_loss           | 144         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.1        |
# |    ep_rew_mean          | 37          |
# |    success_rate         | 0.5         |
# | time/                   |             |
# |    fps                  | 1439        |
# |    iterations           | 21          |
# |    time_elapsed         | 358         |
# |    total_timesteps      | 3612672     |
# | train/                  |             |
# |    approx_kl            | 0.016457848 |
# |    clip_fraction        | 0.184       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.161       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.6        |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | 0.00469     |
# |    std                  | 0.235       |
# |    value_loss           | 147         |
# -----------------------------------------
