# %%
# %load_ext autoreload
# %autoreload 2

import argparse
import os
import sys
import pathlib
from typing import Type, Callable

import gymnasium as gym

sys.modules["gym"] = gym

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from stable_baselines3.common.utils import safe_mean
from stable_baselines3.common.logger import Image
import numpy as np
import matplotlib.pyplot as plt


from swarm.bas import Agent, BASEnv, Blueprint, RenderWrapper, Swarm, wrappers
from swarm.analysis import policy,trajectories, reward
from swarm.training.train import create_parallel_env, SuccessRateCallback, DrawTrajectoriesCallback, RewardHeatmapCallback

# %%
class RelativeGoalInsideGridEnv(gym.Wrapper):
    def __init__(
        self,
        collision_termination: bool = False,
        collision_reward: int = 0,
        distance_reward_transform: Callable[[float], float] = lambda d: -d, 
        window_scale: float | None = 5,
    ):
        blueprint = Blueprint(
            world_size=np.array([200, 200]),
        )
        agent = Agent(
            radius=1,
            max_velocity=1,
            max_acceleration=0.2,
        )
        # Static grid.
        swarm = Swarm(
            num_boids=100,
            radius=2,
            max_velocity=None,
            reset_positions=np.stack(
                np.meshgrid(np.linspace(55, 145, 10), np.linspace(55, 145, 10)), -1
            ).reshape(-1, 2),
            max_acceleration=1,
            separation_range=1,
            cohesion_range=1,
            alignment_range=1,
            steering_weights=(1, 1, 1),
            obstacle_margin=1,
        )
        env = BASEnv(blueprint, agent, swarm)

        target = np.array([100, 100])
        env = wrappers.TargetDirectionAndSectionObservationWrapper(
            env, num_sections=8, max_range=20, position=target, subtract_radius=True
        )
        env = wrappers.TargetRewardWrapper(
            env,
            position=target,
            target_radius=1,
            target_reward=100,
            distance_reward_transform=lambda d: -d
        )
        env = wrappers.BoidCollisionWrapper(
            env,
            collision_termination=collision_termination,
            collision_reward=collision_reward,
            add_reward=True,
        )

        if window_scale is not None:
            env = RenderWrapper(env, window_scale=window_scale)

        env = wrappers.RelativeRotationWrapper(env)
        env = wrappers.FlattenObservationWrapper(env)

        env = gym.wrappers.TimeLimit(env, 500)

        env = wrappers.TrajectoryWrapper(env)

        super().__init__(env)

# %%
train_steps = [
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=False,
            collision_reward=0,
            distance_reward_transform=lambda d: -d,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=False,
            collision_reward=-0.2,
            distance_reward_transform=lambda d: -d,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=False,
            collision_reward=-0.4,
            distance_reward_transform=lambda d: -d,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=False,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d,
            window_scale=window_scale
        ),
    ),
    (
        500000,
        lambda window_scale = None: RelativeGoalInsideGridEnv(
            collision_termination=True,
            collision_reward=-1,
            distance_reward_transform=lambda d: -d / 500,
            window_scale=window_scale
        ),
    )
]

# %%
runs_directory = pathlib.Path("runs")
tensorboard_directory = runs_directory / "tensorboard"

experiment_name = "relative_goal_inside_grid/first_try"
experiment_path = runs_directory / experiment_name

num_processes = 12


model = None
for i, (num_steps, create_env) in enumerate(train_steps):

    env = create_parallel_env(
        create_env,
        num_processes,
        ["is_success", "agent_trajectory"],
    )

    if model is None:
        model = PPO(
            "MlpPolicy",
            env,
            verbose=1,
            tensorboard_log=tensorboard_directory / experiment_name,
        )
    else:
        model.set_env(env)

    model.learn(
        total_timesteps=num_steps,
        # progress_bar=True,
        callback=[SuccessRateCallback(), DrawTrajectoriesCallback(create_env(5)), RewardHeatmapCallback(create_env())],
        reset_num_timesteps=False,
    )

    model.save(experiment_path)
# Out:
# Using cpu device
# Logging to runs/tensorboard/relative_goal_inside_grid/first_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 492      |
# |    ep_rew_mean     | -128     |
# |    success_rate    | 0.0208   |
# | time/              |          |
# |    fps             | 1273     |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 24576    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -128         |
# |    success_rate         | 0.0208       |
# | time/                   |              |
# |    fps                  | 1541         |
# |    iterations           | 2            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0031683997 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.0271      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.531        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000775    |
# |    std                  | 0.992        |
# |    value_loss           | 6.86         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 497       |
# |    ep_rew_mean          | -116      |
# |    success_rate         | 0.03      |
# | time/                   |           |
# |    fps                  | 1633      |
# |    iterations           | 3         |
# |    time_elapsed         | 45        |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0043138 |
# |    clip_fraction        | 0.0332    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.82     |
# |    explained_variance   | 0.431     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.458     |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -0.0023   |
# |    std                  | 0.988     |
# |    value_loss           | 4.82      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 484          |
# |    ep_rew_mean          | -86.7        |
# |    success_rate         | 0.09         |
# | time/                   |              |
# |    fps                  | 1615         |
# |    iterations           | 4            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0052856584 |
# |    clip_fraction        | 0.0561       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.8         |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.79         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00355     |
# |    std                  | 0.981        |
# |    value_loss           | 8.96         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 456          |
# |    ep_rew_mean          | -53.6        |
# |    success_rate         | 0.25         |
# | time/                   |              |
# |    fps                  | 1599         |
# |    iterations           | 5            |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0059164525 |
# |    clip_fraction        | 0.0533       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.5          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00243     |
# |    std                  | 0.971        |
# |    value_loss           | 28.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 419          |
# |    ep_rew_mean          | -17.3        |
# |    success_rate         | 0.48         |
# | time/                   |              |
# |    fps                  | 1598         |
# |    iterations           | 6            |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0064813257 |
# |    clip_fraction        | 0.0746       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.77        |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39           |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00343     |
# |    std                  | 0.967        |
# |    value_loss           | 77.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 32          |
# |    success_rate         | 0.81        |
# | time/                   |             |
# |    fps                  | 1582        |
# |    iterations           | 7           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.008023894 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 84.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00511    |
# |    std                  | 0.956       |
# |    value_loss           | 125         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 214          |
# |    ep_rew_mean          | 68.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1617         |
# |    iterations           | 8            |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0081257885 |
# |    clip_fraction        | 0.0898       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.29         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00478     |
# |    std                  | 0.932        |
# |    value_loss           | 221          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 181         |
# |    ep_rew_mean          | 73.3        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1640        |
# |    iterations           | 9           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 221184      |
# | train/                  |             |
# |    approx_kl            | 0.006882386 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00481    |
# |    std                  | 0.909       |
# |    value_loss           | 292         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | 74.9       |
# |    success_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1661       |
# |    iterations           | 10         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.00755815 |
# |    clip_fraction        | 0.083      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.9       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00466   |
# |    std                  | 0.883      |
# |    value_loss           | 277        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | 77.8         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1681         |
# |    iterations           | 11           |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0061307116 |
# |    clip_fraction        | 0.0659       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.615        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00311     |
# |    std                  | 0.87         |
# |    value_loss           | 233          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 132         |
# |    ep_rew_mean          | 79.3        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 12          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005964617 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.52       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 125         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0034     |
# |    std                  | 0.853       |
# |    value_loss           | 191         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 120          |
# |    ep_rew_mean          | 81.5         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1698         |
# |    iterations           | 13           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 319488       |
# | train/                  |              |
# |    approx_kl            | 0.0055001616 |
# |    clip_fraction        | 0.0572       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.5         |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 90.3         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00258     |
# |    std                  | 0.843        |
# |    value_loss           | 166          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 122         |
# |    ep_rew_mean          | 80.9        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 14          |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.006299122 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.46       |
# |    explained_variance   | 0.81        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.5        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 0.828       |
# |    value_loss           | 139         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 114          |
# |    ep_rew_mean          | 81.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1689         |
# |    iterations           | 15           |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0055547194 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | 0.824        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.5         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00318     |
# |    std                  | 0.814        |
# |    value_loss           | 122          |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 109       |
# |    ep_rew_mean          | 82.9      |
# |    success_rate         | 1         |
# | time/                   |           |
# |    fps                  | 1702      |
# |    iterations           | 16        |
# |    time_elapsed         | 231       |
# |    total_timesteps      | 393216    |
# | train/                  |           |
# |    approx_kl            | 0.0050891 |
# |    clip_fraction        | 0.0593    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.4      |
# |    explained_variance   | 0.845     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 54.7      |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -0.00263  |
# |    std                  | 0.805     |
# |    value_loss           | 107       |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 82.1         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1713         |
# |    iterations           | 17           |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 417792       |
# | train/                  |              |
# |    approx_kl            | 0.0065789013 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.36        |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.1         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00294     |
# |    std                  | 0.788        |
# |    value_loss           | 94.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 103          |
# |    ep_rew_mean          | 83.7         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1721         |
# |    iterations           | 18           |
# |    time_elapsed         | 256          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0049639978 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.34        |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.5         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00171     |
# |    std                  | 0.779        |
# |    value_loss           | 82.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 102          |
# |    ep_rew_mean          | 83.8         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1728         |
# |    iterations           | 19           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 0.0049250303 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00076     |
# |    std                  | 0.769        |
# |    value_loss           | 78.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | 82.8        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1735        |
# |    iterations           | 20          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.004650391 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00139    |
# |    std                  | 0.761       |
# |    value_loss           | 74.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 97.9         |
# |    ep_rew_mean          | 84.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 21           |
# |    time_elapsed         | 296          |
# |    total_timesteps      | 516096       |
# | train/                  |              |
# |    approx_kl            | 0.0048071407 |
# |    clip_fraction        | 0.0547       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.869        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00194     |
# |    std                  | 0.749        |
# |    value_loss           | 69.5         |
# ------------------------------------------
# /Users/leon/Projects/TUM/ADLR/tum-adlr-ws22-04/venv/lib/python3.10/site-packages/stable_baselines3/common/save_util.py:278: UserWarning: Path 'runs/relative_goal_inside_grid' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
# Logging to runs/tensorboard/relative_goal_inside_grid/first_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.7     |
# |    ep_rew_mean     | 80.8     |
# |    success_rate    | 1        |
# | time/              |          |
# |    fps             | 1442     |
# |    iterations      | 1        |
# |    time_elapsed    | 17       |
# |    total_timesteps | 540672   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 101          |
# |    ep_rew_mean          | 80.1         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1652         |
# |    iterations           | 2            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 565248       |
# | train/                  |              |
# |    approx_kl            | 0.0051352377 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.2         |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.725        |
# |    value_loss           | 70           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.8        |
# |    ep_rew_mean          | 81          |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 3           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.004653827 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000737   |
# |    std                  | 0.717       |
# |    value_loss           | 66.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.8         |
# |    ep_rew_mean          | 82.6         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1706         |
# |    iterations           | 4            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0051179472 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00121     |
# |    std                  | 0.706        |
# |    value_loss           | 64.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.1        |
# |    ep_rew_mean          | 81.8        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1740        |
# |    iterations           | 5           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.005668537 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.2        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00213    |
# |    std                  | 0.697       |
# |    value_loss           | 66.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.9         |
# |    ep_rew_mean          | 81.2         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1753         |
# |    iterations           | 6            |
# |    time_elapsed         | 84           |
# |    total_timesteps      | 663552       |
# | train/                  |              |
# |    approx_kl            | 0.0053038322 |
# |    clip_fraction        | 0.0501       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.876        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33           |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0017      |
# |    std                  | 0.688        |
# |    value_loss           | 61.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.2         |
# |    ep_rew_mean          | 81.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1775         |
# |    iterations           | 7            |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0052397083 |
# |    clip_fraction        | 0.0537       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.06        |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.002       |
# |    std                  | 0.673        |
# |    value_loss           | 62.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.8        |
# |    ep_rew_mean          | 81.1        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1738        |
# |    iterations           | 8           |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 712704      |
# | train/                  |             |
# |    approx_kl            | 0.004305406 |
# |    clip_fraction        | 0.046       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.000772   |
# |    std                  | 0.667       |
# |    value_loss           | 63          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.2         |
# |    ep_rew_mean          | 80.6         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1719         |
# |    iterations           | 9            |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0056676506 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.9         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00105     |
# |    std                  | 0.658        |
# |    value_loss           | 62.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92.6        |
# |    ep_rew_mean          | 82.1        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1688        |
# |    iterations           | 10          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.005302837 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.3        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0014     |
# |    std                  | 0.654       |
# |    value_loss           | 61          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.9         |
# |    ep_rew_mean          | 83.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1652         |
# |    iterations           | 11           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0049808244 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.97        |
# |    explained_variance   | 0.875        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.1         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00191     |
# |    std                  | 0.65         |
# |    value_loss           | 59.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.5         |
# |    ep_rew_mean          | 83.3         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1616         |
# |    iterations           | 12           |
# |    time_elapsed         | 182          |
# |    total_timesteps      | 811008       |
# | train/                  |              |
# |    approx_kl            | 0.0046348204 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30           |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.642        |
# |    value_loss           | 61.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.9        |
# |    ep_rew_mean          | 81.8        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1595        |
# |    iterations           | 13          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.005029508 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.93       |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000806   |
# |    std                  | 0.636       |
# |    value_loss           | 58.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92          |
# |    ep_rew_mean          | 81.5        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1573        |
# |    iterations           | 14          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 860160      |
# | train/                  |             |
# |    approx_kl            | 0.004801816 |
# |    clip_fraction        | 0.0485      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00135    |
# |    std                  | 0.631       |
# |    value_loss           | 57.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.3         |
# |    ep_rew_mean          | 83.8         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1539         |
# |    iterations           | 15           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0046386435 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.1         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00103     |
# |    std                  | 0.626        |
# |    value_loss           | 57.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.2         |
# |    ep_rew_mean          | 82.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1526         |
# |    iterations           | 16           |
# |    time_elapsed         | 257          |
# |    total_timesteps      | 909312       |
# | train/                  |              |
# |    approx_kl            | 0.0042249733 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.873        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.7         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 0.627        |
# |    value_loss           | 59.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.5         |
# |    ep_rew_mean          | 82.6         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1520         |
# |    iterations           | 17           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0056491527 |
# |    clip_fraction        | 0.0527       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.6         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.619        |
# |    value_loss           | 55.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 92          |
# |    ep_rew_mean          | 81.6        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1498        |
# |    iterations           | 18          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.005200551 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00106    |
# |    std                  | 0.613       |
# |    value_loss           | 55.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89           |
# |    ep_rew_mean          | 82.6         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1498         |
# |    iterations           | 19           |
# |    time_elapsed         | 311          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0051076333 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.83        |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 0.605        |
# |    value_loss           | 55.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.4        |
# |    ep_rew_mean          | 82.1        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 20          |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 1007616     |
# | train/                  |             |
# |    approx_kl            | 0.006123461 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.1        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00199    |
# |    std                  | 0.595       |
# |    value_loss           | 55          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.9         |
# |    ep_rew_mean          | 84.2         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1509         |
# |    iterations           | 21           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 1032192      |
# | train/                  |              |
# |    approx_kl            | 0.0046586962 |
# |    clip_fraction        | 0.0472       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.8         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000692    |
# |    std                  | 0.588        |
# |    value_loss           | 53.6         |
# ------------------------------------------
# Logging to runs/tensorboard/relative_goal_inside_grid/first_try/PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.4     |
# |    ep_rew_mean     | 80.4     |
# |    success_rate    | 1        |
# | time/              |          |
# |    fps             | 1236     |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1056768  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.1       |
# |    ep_rew_mean          | 81.4       |
# |    success_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1468       |
# |    iterations           | 2          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 1081344    |
# | train/                  |            |
# |    approx_kl            | 0.00502672 |
# |    clip_fraction        | 0.0527     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.74      |
# |    explained_variance   | 0.886      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.5       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00105   |
# |    std                  | 0.576      |
# |    value_loss           | 52.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 87.6       |
# |    ep_rew_mean          | 79.4       |
# |    success_rate         | 1          |
# | time/                   |            |
# |    fps                  | 1560       |
# |    iterations           | 3          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 1105920    |
# | train/                  |            |
# |    approx_kl            | 0.00489884 |
# |    clip_fraction        | 0.0495     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 0.883      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.5       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.001     |
# |    std                  | 0.57       |
# |    value_loss           | 56         |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.7        |
# |    ep_rew_mean          | 77.5        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1471        |
# |    iterations           | 4           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 1130496     |
# | train/                  |             |
# |    approx_kl            | 0.005503925 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00102    |
# |    std                  | 0.565       |
# |    value_loss           | 55.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.7         |
# |    ep_rew_mean          | 79.9         |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1402         |
# |    iterations           | 5            |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 1155072      |
# | train/                  |              |
# |    approx_kl            | 0.0055673853 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000687    |
# |    std                  | 0.559        |
# |    value_loss           | 57.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.6        |
# |    ep_rew_mean          | 81.4        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1380        |
# |    iterations           | 6           |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.005711101 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.9        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00117    |
# |    std                  | 0.548       |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.2        |
# |    ep_rew_mean          | 80.6        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1380        |
# |    iterations           | 7           |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 1204224     |
# | train/                  |             |
# |    approx_kl            | 0.006002709 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.2        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00158    |
# |    std                  | 0.541       |
# |    value_loss           | 58          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.5         |
# |    ep_rew_mean          | 80           |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 1366         |
# |    iterations           | 8            |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 1228800      |
# | train/                  |              |
# |    approx_kl            | 0.0056367046 |
# |    clip_fraction        | 0.0546       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.59        |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00136     |
# |    std                  | 0.533        |
# |    value_loss           | 56.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 89.6        |
# |    ep_rew_mean          | 78.5        |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 1359        |
# |    iterations           | 9           |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 1253376     |
# | train/                  |             |
# |    approx_kl            | 0.005741119 |
# ...
# |    clip_fraction        | 0.095        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.849       |
# |    explained_variance   | 0.739        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64           |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00152     |
# |    std                  | 0.37         |
# |    value_loss           | 49.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.9         |
# |    ep_rew_mean          | -2.6         |
# |    success_rate         | 0.07         |
# | time/                   |              |
# |    fps                  | 1270         |
# |    iterations           | 6            |
# |    time_elapsed         | 116          |
# |    total_timesteps      | 2211840      |
# | train/                  |              |
# |    approx_kl            | 0.0076023596 |
# |    clip_fraction        | 0.095        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.837       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.7         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00161     |
# |    std                  | 0.369        |
# |    value_loss           | 48.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39          |
# |    ep_rew_mean          | -7.43       |
# |    success_rate         | 0.03        |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 7           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 2236416     |
# | train/                  |             |
# |    approx_kl            | 0.007862997 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.831      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.4        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.001      |
# |    std                  | 0.365       |
# |    value_loss           | 52.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.7         |
# |    ep_rew_mean          | -5.56        |
# |    success_rate         | 0.05         |
# | time/                   |              |
# |    fps                  | 1281         |
# |    iterations           | 8            |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 2260992      |
# | train/                  |              |
# |    approx_kl            | 0.0074403663 |
# |    clip_fraction        | 0.0933       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.6         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00139     |
# |    std                  | 0.363        |
# |    value_loss           | 52.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | -6.74       |
# |    success_rate         | 0.07        |
# | time/                   |             |
# |    fps                  | 1278        |
# |    iterations           | 9           |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 2285568     |
# | train/                  |             |
# |    approx_kl            | 0.007833076 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.794      |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00112    |
# |    std                  | 0.359       |
# |    value_loss           | 49.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 44.9        |
# |    ep_rew_mean          | -8.47       |
# |    success_rate         | 0.04        |
# | time/                   |             |
# |    fps                  | 1282        |
# |    iterations           | 10          |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 2310144     |
# | train/                  |             |
# |    approx_kl            | 0.007274876 |
# |    clip_fraction        | 0.097       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.765      |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0014     |
# |    std                  | 0.353       |
# |    value_loss           | 47.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | -4.21       |
# |    success_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 11          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 2334720     |
# | train/                  |             |
# |    approx_kl            | 0.007960102 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.812       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.1        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0018     |
# |    std                  | 0.351       |
# |    value_loss           | 43.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.6        |
# |    ep_rew_mean          | -5.37       |
# |    success_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 1276        |
# |    iterations           | 12          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 2359296     |
# | train/                  |             |
# |    approx_kl            | 0.007995591 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.727      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0015     |
# |    std                  | 0.349       |
# |    value_loss           | 47.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.1        |
# |    ep_rew_mean          | -2.59       |
# |    success_rate         | 0.08        |
# | time/                   |             |
# |    fps                  | 1274        |
# |    iterations           | 13          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 2383872     |
# | train/                  |             |
# |    approx_kl            | 0.008772868 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.8        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0019     |
# |    std                  | 0.342       |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.5        |
# |    ep_rew_mean          | -0.814      |
# |    success_rate         | 0.1         |
# | time/                   |             |
# |    fps                  | 1277        |
# |    iterations           | 14          |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 2408448     |
# | train/                  |             |
# |    approx_kl            | 0.008000972 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00137    |
# |    std                  | 0.338       |
# |    value_loss           | 49          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.4         |
# |    ep_rew_mean          | -1.48        |
# |    success_rate         | 0.09         |
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 15           |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 2433024      |
# | train/                  |              |
# |    approx_kl            | 0.0077598277 |
# |    clip_fraction        | 0.0911       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 980          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 0.336        |
# |    value_loss           | 56.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.7        |
# |    ep_rew_mean          | -3.62       |
# |    success_rate         | 0.07        |
# | time/                   |             |
# |    fps                  | 1280        |
# |    iterations           | 16          |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 2457600     |
# | train/                  |             |
# |    approx_kl            | 0.008481368 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.624      |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.329       |
# |    value_loss           | 45.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42          |
# |    ep_rew_mean          | -5.33       |
# |    success_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 1284        |
# |    iterations           | 17          |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 2482176     |
# | train/                  |             |
# |    approx_kl            | 0.008382863 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.594      |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.9        |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00131    |
# |    std                  | 0.325       |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.5        |
# |    ep_rew_mean          | -7.88       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 1290        |
# |    iterations           | 18          |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 2506752     |
# | train/                  |             |
# |    approx_kl            | 0.007868647 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.2        |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.000234   |
# |    std                  | 0.321       |
# |    value_loss           | 39.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 38.5       |
# |    ep_rew_mean          | -5.07      |
# |    success_rate         | 0.05       |
# | time/                   |            |
# |    fps                  | 1293       |
# |    iterations           | 19         |
# |    time_elapsed         | 361        |
# |    total_timesteps      | 2531328    |
# | train/                  |            |
# |    approx_kl            | 0.00820811 |
# |    clip_fraction        | 0.1        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.544     |
# |    explained_variance   | 0.85       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 34.5       |
# |    n_updates            | 1020       |
# |    policy_gradient_loss | -0.00172   |
# |    std                  | 0.318      |
# |    value_loss           | 47.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38          |
# |    ep_rew_mean          | -5.25       |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 1297        |
# |    iterations           | 20          |
# |    time_elapsed         | 378         |
# |    total_timesteps      | 2555904     |
# | train/                  |             |
# |    approx_kl            | 0.007443882 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.85        |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | 2.62e-05    |
# |    std                  | 0.317       |
# |    value_loss           | 46.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.9        |
# |    ep_rew_mean          | -5.18       |
# |    success_rate         | 0.05        |
# | time/                   |             |
# |    fps                  | 1291        |
# |    iterations           | 21          |
# |    time_elapsed         | 399         |
# |    total_timesteps      | 2580480     |
# | train/                  |             |
# |    approx_kl            | 0.008318987 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.8        |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | -0.000962   |
# |    std                  | 0.314       |
# |    value_loss           | 45.4        |
# -----------------------------------------
